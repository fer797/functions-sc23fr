# %%
# Updating the file paths with the specified directory
file_path_prefix = "fhir-fastapiapp/"

# List of CSV files with updated paths
csv_files = [
    f"{file_path_prefix}CPU Saturation (Load1 per CPU)-data-2024-08-06 08_32_33.csv",
    f"{file_path_prefix}CPU Usage-data-2024-08-06 08_30_16.csv",
    f"{file_path_prefix}CPU Utilisation-data-2024-08-06 08_32_27.csv",
    f"{file_path_prefix}CPU usage-data-2024-08-06 08_49_17.csv",
    f"{file_path_prefix}Cgroup manager operation rate-data-as-joinbyfield-2024-08-06 08_48_31.csv",
    f"{file_path_prefix}Disk IO Saturation-data-2024-08-06 08_33_04.csv",
    f"{file_path_prefix}Disk IO Utilisation-data-2024-08-06 08_32_59.csv",
    f"{file_path_prefix}Disk I_O-data-as-joinbyfield-2024-08-06 08_30_54.csv",
    f"{file_path_prefix}Load Average-data-as-joinbyfield-2024-08-06 08_30_24.csv",
    f"{file_path_prefix}Memory Saturation (Major Page Faults)-data-2024-08-06 08_32_43.csv",
    f"{file_path_prefix}Memory Usage-data-2024-08-06 08_30_44.csv",
    f"{file_path_prefix}Memory Usage-data-as-joinbyfield-2024-08-06 08_30_36.csv",
    f"{file_path_prefix}Memory Utilisation-data-2024-08-06 08_32_38.csv",
    f"{file_path_prefix}Memory-data-2024-08-06 08_49_10.csv",
    f"{file_path_prefix}Network Received-data-as-joinbyfield-2024-08-06 08_31_05.csv",
    f"{file_path_prefix}Network Transmitted-data-as-joinbyfield-2024-08-06 08_31_26.csv",
    f"{file_path_prefix}Network Utilisation (Bytes Receive_Transmit)-data-2024-08-06 08_32_49.csv",
    f"{file_path_prefix}Network Utilisation (Bytes Receive_Transmit)-data-2024-08-06 08_32_50.csv",
    f"{file_path_prefix}Observed Concurrency-data-as-joinbyfield-2024-08-06 08_23_11.csv",
    f"{file_path_prefix}PLEG relist duration-data-2024-08-06 08_48_44.csv",
    f"{file_path_prefix}Pod Counts-data-as-joinbyfield-2024-08-06 08_19_29.csv",
    f"{file_path_prefix}Pod Memory Usage-data-2024-08-06 08_19_16.csv",
    f"{file_path_prefix}Pod Start Duration-data-as-joinbyfield-2024-08-06 08_47_55.csv",
    f"{file_path_prefix}Pod Start Rate-data-as-joinbyfield-2024-08-06 08_48_04 (1).csv",
    f"{file_path_prefix}Pod Start Rate-data-as-joinbyfield-2024-08-06 08_48_04.csv",
    f"{file_path_prefix}RPC rate-data-as-joinbyfield-2024-08-06 08_48_52.csv",
    f"{file_path_prefix}Reconcile Count (per min)-data-as-joinbyfield-2024-08-06 08_26_54.csv",
    f"{file_path_prefix}Request Concurrency-data-2024-08-06 08_18_40.csv",
    f"{file_path_prefix}Request Concurrency-data-2024-08-06 08_24_27.csv",
    f"{file_path_prefix}Request Count in last minute by Response Code-data-2024-08-06 08_23_41.csv",
    f"{file_path_prefix}Request Volume-data-2024-08-06 08_25_20.csv",
    f"{file_path_prefix}Request duration 99th quantile-data-as-joinbyfield-2024-08-06 08_49_01.csv",
    f"{file_path_prefix}Response Time in last minute-data-as-joinbyfield-2024-08-06 08_24_02.csv",
    f"{file_path_prefix}Revision CPU Usage-data-as-joinbyfield-2024-08-06 08_19_02.csv",
    f"{file_path_prefix}Revision Pod Counts-data-as-joinbyfield-2024-08-06 08_18_08.csv",
    f"{file_path_prefix}Storage Operation Duration 99th quantile-data-as-joinbyfield-2024-08-06 08_48_23.csv",
    f"{file_path_prefix}Storage Operation Rate-data-as-joinbyfield-2024-08-06 08_48_12.csv",
    f"{file_path_prefix}knative.dev.serving.pkg.reconciler.configuration.Reconciler Reconcile Count (per min)-data-2024-08-06 08_27_06.csv"
]

# Dictionary to store the dataframes
dataframes = {}

# Read and store dataframes
for file in csv_files:
    try:
        df = pd.read_csv(file)
        dataframes[file] = df
    except Exception as e:
        print(f"Error reading {file}: {e}")

# Print columns and head for each dataframe
for file, df in dataframes.items():
    print(f"\nFile: {file}")
    print("Columns:", df.columns.tolist())
    print("Head:\n", df.head(), "\n")
# Out:
# Error reading fhir-fastapiapp/CPU Saturation (Load1 per CPU)-data-2024-08-06 08_32_33.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/CPU Saturation (Load1 per CPU)-data-2024-08-06 08_32_33.csv'
# Error reading fhir-fastapiapp/CPU Usage-data-2024-08-06 08_30_16.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/CPU Usage-data-2024-08-06 08_30_16.csv'
# Error reading fhir-fastapiapp/CPU Utilisation-data-2024-08-06 08_32_27.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/CPU Utilisation-data-2024-08-06 08_32_27.csv'
# Error reading fhir-fastapiapp/CPU usage-data-2024-08-06 08_49_17.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/CPU usage-data-2024-08-06 08_49_17.csv'
# Error reading fhir-fastapiapp/Cgroup manager operation rate-data-as-joinbyfield-2024-08-06 08_48_31.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Cgroup manager operation rate-data-as-joinbyfield-2024-08-06 08_48_31.csv'
# Error reading fhir-fastapiapp/Disk IO Saturation-data-2024-08-06 08_33_04.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Disk IO Saturation-data-2024-08-06 08_33_04.csv'
# Error reading fhir-fastapiapp/Disk IO Utilisation-data-2024-08-06 08_32_59.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Disk IO Utilisation-data-2024-08-06 08_32_59.csv'
# Error reading fhir-fastapiapp/Disk I_O-data-as-joinbyfield-2024-08-06 08_30_54.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Disk I_O-data-as-joinbyfield-2024-08-06 08_30_54.csv'
# Error reading fhir-fastapiapp/Load Average-data-as-joinbyfield-2024-08-06 08_30_24.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Load Average-data-as-joinbyfield-2024-08-06 08_30_24.csv'
# Error reading fhir-fastapiapp/Memory Saturation (Major Page Faults)-data-2024-08-06 08_32_43.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Memory Saturation (Major Page Faults)-data-2024-08-06 08_32_43.csv'
# Error reading fhir-fastapiapp/Memory Usage-data-2024-08-06 08_30_44.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Memory Usage-data-2024-08-06 08_30_44.csv'
# Error reading fhir-fastapiapp/Memory Usage-data-as-joinbyfield-2024-08-06 08_30_36.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Memory Usage-data-as-joinbyfield-2024-08-06 08_30_36.csv'
# Error reading fhir-fastapiapp/Memory Utilisation-data-2024-08-06 08_32_38.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Memory Utilisation-data-2024-08-06 08_32_38.csv'
# Error reading fhir-fastapiapp/Memory-data-2024-08-06 08_49_10.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Memory-data-2024-08-06 08_49_10.csv'
# Error reading fhir-fastapiapp/Network Received-data-as-joinbyfield-2024-08-06 08_31_05.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Network Received-data-as-joinbyfield-2024-08-06 08_31_05.csv'
# Error reading fhir-fastapiapp/Network Transmitted-data-as-joinbyfield-2024-08-06 08_31_26.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Network Transmitted-data-as-joinbyfield-2024-08-06 08_31_26.csv'
# Error reading fhir-fastapiapp/Network Utilisation (Bytes Receive_Transmit)-data-2024-08-06 08_32_49.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Network Utilisation (Bytes Receive_Transmit)-data-2024-08-06 08_32_49.csv'
# Error reading fhir-fastapiapp/Network Utilisation (Bytes Receive_Transmit)-data-2024-08-06 08_32_50.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Network Utilisation (Bytes Receive_Transmit)-data-2024-08-06 08_32_50.csv'
# Error reading fhir-fastapiapp/Observed Concurrency-data-as-joinbyfield-2024-08-06 08_23_11.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Observed Concurrency-data-as-joinbyfield-2024-08-06 08_23_11.csv'
# Error reading fhir-fastapiapp/PLEG relist duration-data-2024-08-06 08_48_44.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/PLEG relist duration-data-2024-08-06 08_48_44.csv'
# Error reading fhir-fastapiapp/Pod Counts-data-as-joinbyfield-2024-08-06 08_19_29.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Pod Counts-data-as-joinbyfield-2024-08-06 08_19_29.csv'
# Error reading fhir-fastapiapp/Pod Memory Usage-data-2024-08-06 08_19_16.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Pod Memory Usage-data-2024-08-06 08_19_16.csv'
# Error reading fhir-fastapiapp/Pod Start Duration-data-as-joinbyfield-2024-08-06 08_47_55.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Pod Start Duration-data-as-joinbyfield-2024-08-06 08_47_55.csv'
# Error reading fhir-fastapiapp/Pod Start Rate-data-as-joinbyfield-2024-08-06 08_48_04 (1).csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Pod Start Rate-data-as-joinbyfield-2024-08-06 08_48_04 (1).csv'
# Error reading fhir-fastapiapp/Pod Start Rate-data-as-joinbyfield-2024-08-06 08_48_04.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Pod Start Rate-data-as-joinbyfield-2024-08-06 08_48_04.csv'
# Error reading fhir-fastapiapp/RPC rate-data-as-joinbyfield-2024-08-06 08_48_52.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/RPC rate-data-as-joinbyfield-2024-08-06 08_48_52.csv'
# Error reading fhir-fastapiapp/Reconcile Count (per min)-data-as-joinbyfield-2024-08-06 08_26_54.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Reconcile Count (per min)-data-as-joinbyfield-2024-08-06 08_26_54.csv'
# Error reading fhir-fastapiapp/Request Concurrency-data-2024-08-06 08_18_40.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Request Concurrency-data-2024-08-06 08_18_40.csv'
# Error reading fhir-fastapiapp/Request Concurrency-data-2024-08-06 08_24_27.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Request Concurrency-data-2024-08-06 08_24_27.csv'
# Error reading fhir-fastapiapp/Request Count in last minute by Response Code-data-2024-08-06 08_23_41.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Request Count in last minute by Response Code-data-2024-08-06 08_23_41.csv'
# Error reading fhir-fastapiapp/Request Volume-data-2024-08-06 08_25_20.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Request Volume-data-2024-08-06 08_25_20.csv'
# Error reading fhir-fastapiapp/Request duration 99th quantile-data-as-joinbyfield-2024-08-06 08_49_01.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Request duration 99th quantile-data-as-joinbyfield-2024-08-06 08_49_01.csv'
# Error reading fhir-fastapiapp/Response Time in last minute-data-as-joinbyfield-2024-08-06 08_24_02.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Response Time in last minute-data-as-joinbyfield-2024-08-06 08_24_02.csv'
# Error reading fhir-fastapiapp/Revision CPU Usage-data-as-joinbyfield-2024-08-06 08_19_02.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Revision CPU Usage-data-as-joinbyfield-2024-08-06 08_19_02.csv'
# Error reading fhir-fastapiapp/Revision Pod Counts-data-as-joinbyfield-2024-08-06 08_18_08.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Revision Pod Counts-data-as-joinbyfield-2024-08-06 08_18_08.csv'
# Error reading fhir-fastapiapp/Storage Operation Duration 99th quantile-data-as-joinbyfield-2024-08-06 08_48_23.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Storage Operation Duration 99th quantile-data-as-joinbyfield-2024-08-06 08_48_23.csv'
# Error reading fhir-fastapiapp/Storage Operation Rate-data-as-joinbyfield-2024-08-06 08_48_12.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/Storage Operation Rate-data-as-joinbyfield-2024-08-06 08_48_12.csv'
# Error reading fhir-fastapiapp/knative.dev.serving.pkg.reconciler.configuration.Reconciler Reconcile Count (per min)-data-2024-08-06 08_27_06.csv: [Errno 2] No such file or directory: 'fhir-fastapiapp/knative.dev.serving.pkg.reconciler.configuration.Reconciler Reconcile Count (per min)-data-2024-08-06 08_27_06.csv'

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Function to clean and convert columns to numeric
def clean_cpu_data(df, time_col, value_col):
    df[time_col] = pd.to_datetime(df[time_col])
    df[value_col] = df[value_col].str.replace('%', '').astype(float)
    return df

# Extract and clean data from relevant files
cpu_saturation_df = clean_cpu_data(dataframes['fhir-fastapiapp/CPU Saturation (Load1 per CPU)-data-2024-08-06 08_32_33.csv'], 'Time', '192.168.49.2:9100')
cpu_usage_df = clean_cpu_data(dataframes['fhir-fastapiapp/CPU Usage-data-2024-08-06 08_30_16.csv'], 'Time', '0')
cpu_utilisation_df = clean_cpu_data(dataframes['fhir-fastapiapp/CPU Utilisation-data-2024-08-06 08_32_27.csv'], 'Time', '192.168.49.2:9100')
cpu_usage_2_df = dataframes['fhir-fastapiapp/CPU usage-data-2024-08-06 08_49_17.csv']
cpu_usage_2_df['Time'] = pd.to_datetime(cpu_usage_2_df['Time'])
cpu_usage_2_df['192.168.49.2:10250'] = cpu_usage_2_df['192.168.49.2:10250'].astype(float)

# Plotting the data
plt.figure(figsize=(14, 10))

# CPU Saturation (Load1 per CPU)
plt.subplot(2, 2, 1)
plt.plot(cpu_saturation_df['Time'], cpu_saturation_df['192.168.49.2:9100'], label='CPU Saturation (Load1 per CPU)')
plt.xlabel('Time')
plt.ylabel('Load1 per CPU (%)')
plt.title('CPU Saturation (Load1 per CPU)')
plt.legend()

# CPU Usage
plt.subplot(2, 2, 2)
plt.plot(cpu_usage_df['Time'], cpu_usage_df['0'], label='CPU Usage')
plt.xlabel('Time')
plt.ylabel('CPU Usage (%)')
plt.title('CPU Usage')
plt.legend()

# CPU Utilisation
plt.subplot(2, 2, 3)
plt.plot(cpu_utilisation_df['Time'], cpu_utilisation_df['192.168.49.2:9100'], label='CPU Utilisation')
plt.xlabel('Time')
plt.ylabel('CPU Utilisation (%)')
plt.title('CPU Utilisation')
plt.legend()

# CPU usage (2nd file)
plt.subplot(2, 2, 4)
plt.plot(cpu_usage_2_df['Time'], cpu_usage_2_df['192.168.49.2:10250'], label='CPU Usage 2')
plt.xlabel('Time')
plt.ylabel('CPU Usage')
plt.title('CPU Usage 2')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 11
#       8     return df
#      10 # Extract and clean data from relevant files
# ---> 11 cpu_saturation_df = clean_cpu_data(dataframes['fhir-fastapiapp/CPU Saturation (Load1 per CPU)-data-2024-08-06 08_32_33.csv'], 'Time', '192.168.49.2:9100')
#      12 cpu_usage_df = clean_cpu_data(dataframes['fhir-fastapiapp/CPU Usage-data-2024-08-06 08_30_16.csv'], 'Time', '0')
#      13 cpu_utilisation_df = clean_cpu_data(dataframes['fhir-fastapiapp/CPU Utilisation-data-2024-08-06 08_32_27.csv'], 'Time', '192.168.49.2:9100')
#
# NameError: name 'dataframes' is not defined
